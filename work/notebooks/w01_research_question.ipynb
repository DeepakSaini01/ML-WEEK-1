# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepakSaini01/ML-WEEK-1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/DeepakSaini01/ML-WEEK-1.git
# Out:
# Cloning into 'ML-WEEK-1'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 124 (delta 38), reused 98 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (124/124), 1.82 MiB | 17.27 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# %cd /content/ML-WEEK-1
# Out:
# /content/ML-WEEK-1

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DeepakSaini01/ML-WEEK-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am choosing the Low CTR Recovery Lane. This beginner-friendly lane focuses on identifying high-impression pages that suffer from an underperforming Click-Through Rate (CTR). This approach allows me to master the baseline ML workflow using intuitive features before moving to complex models. It provides immediate value by pinpointing "quick-win" pages where small fixes could rapidly recover lost traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Check the shape of our starter dataset to confirm setup
import pandas as pd

data_path = "data/raw/content_refresh_anonymized.csv"
try:
    df = pd.read_csv(data_path)
    print(f"Dataset successfully loaded! Total pages available: {df.shape[0]}")
    print(f"Number of tracking features: {df.shape[1]}")
except Exception as e:
    print(f"Error loading data: {e}. Please ensure you are running this from the root of your repository copy.")
# Out:
# Dataset successfully loaded! Total pages available: 30000
# Number of tracking features: 44

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# What decision does this improve?
#  It helps decide which pages to select first for basic title, meta description, or introduction updates.
#
# Who acts on it?
#  Content writers and SEO interns act on this list to make quick tactical updates.
#
# What does a wrong recommendation cost?
#  A wrong recommendation costs about 15–30 minutes of a writer's time reviewing a page that doesn't actually need adjustments. Missing a good page means leaving free, easy search traffic on the table for competitors to take.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Let's check the first few column names to verify what basic metrics we have
if 'df' in locals():
    print("Available metrics for beginner data profiling:")
    print(list(df.columns[:5]))  # Showing just the top 5 columns for simplicity
else:
    print("DataFrame not found. Please run Section 1 first.")
# Out:
# Available metrics for beginner data profiling:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level']

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# By examining our starter file content_refresh_anonymized.csv, we can pull out three basic real numbers that validate this lane:
#
# Total Rows Available: The dataset gives us a robust sample size of individual page records to analyze.
#
# Feature Count: There are plenty of calculated attributes per row to help map out traffic performance.
#
# Data Cleanliness: There are zero completely missing or null values in the core matrix, making it perfect for a clean, error-free beginner implementation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Pulling basic numbers from our loaded dataset
if 'df' in locals():
    total_pages = len(df)
    total_features = len(df.columns)
    missing_values = df.isnull().sum().sum()

    print(f"Real Number 1: Total rows to analyze = {total_pages}")
    print(f"Real Number 2: Total columns available = {total_features}")
    print(f"Real Number 3: Total missing values = {missing_values}")
else:
    print("DataFrame tracking object missing.")
# Out:
# Real Number 1: Total rows to analyze = 30000
# Real Number 2: Total columns available = 44
# Real Number 3: Total missing values = 73868

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# What this work WILL say: This analysis offers directional decision-support based strictly on observed historical trends in our data. It highlights which pages look like the best candidates for optimization.
#
# What this work WILL NEVER say: This work cannot prove causal relationships, nor does it claim to predict Google's sorting algorithm. It is purely an internal helper tool to organize a team's weekly work queue.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Final validation to confirm our file environment runs cleanly top-to-bottom
print("Framing check complete. Project parameters safely locked to decision-support metrics.")
# Out:
# Framing check complete. Project parameters safely locked to decision-support metrics.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
